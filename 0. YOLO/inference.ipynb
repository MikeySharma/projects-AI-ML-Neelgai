# %%
# !pip install ultralytics
# Out:
# Requirement already satisfied: ultralytics in c:\users\ghost\appdata\roaming\python\python38\site-packages (8.0.228)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: numpy>=1.22.2 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (1.24.3)
# Requirement already satisfied: opencv-python>=4.6.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\ghost\appdata\roaming\python\python38\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (1.10.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (2.4.1)
# Collecting torchvision>=0.9.0 (from ultralytics)
#   Using cached torchvision-0.19.1-cp38-cp38-win_amd64.whl.metadata (6.1 kB)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (2.0.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: psutil in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from ultralytics) (5.9.0)
# Collecting py-cpuinfo (from ultralytics)
#   Using cached py_cpuinfo-9.0.0-py3-none-any.whl.metadata (794 bytes)
# Requirement already satisfied: thop>=0.1.1 in c:\users\ghost\appdata\roaming\python\python38\site-packages (from ultralytics) (0.1.1.post2209072238)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (6.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from requests>=2.23.0->ultralytics) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\ghost\appdata\roaming\python\python38\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\ghost\appdata\roaming\python\python38\site-packages (from torch>=1.8.0->ultralytics) (3.1)
# Requirement already satisfied: jinja2 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: colorama in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from importlib-resources>=3.2.0->matplotlib>=3.3.0->ultralytics) (3.19.2)
# Requirement already satisfied: six>=1.5 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ghost\anaconda3\envs\prime\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# Using cached torchvision-0.19.1-cp38-cp38-win_amd64.whl (1.3 MB)
# Using cached py_cpuinfo-9.0.0-py3-none-any.whl (22 kB)
# Installing collected packages: py-cpuinfo, torchvision
# Successfully installed py-cpuinfo-9.0.0 torchvision-0.19.1

# %% [markdown]
# # Import Libraries

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot  as plt

# %% [markdown]
# # Load Model

# %%
# Load a model
model = YOLO('runs/detect/train/weights/best.pt')  # pretrained YOLOv8n model
# model = YOLO('yolov8x')
# Out:
# WARNING ⚠️ runs/detect/train/weights/best.pt appears to require 'dill', which is not in ultralytics requirements.
# AutoInstall will run now for 'dill' but this feature will be removed in the future.
# Recommend fixes are to train a new model using the latest 'ultralytics' package or to run a command with an official YOLOv8 model, i.e. 'yolo predict model=yolov8n.pt'
# C:\Users\Ghost\AppData\Roaming\Python\Python38\site-packages\ultralytics\nn\tasks.py:567: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load
# requirements: Ultralytics requirement ['dill'] not found, attempting AutoUpdate...
# Collecting dill
#   Downloading dill-0.3.9-py3-none-any.whl.metadata (10 kB)
# Downloading dill-0.3.9-py3-none-any.whl (119 kB)
#    -------------------------------------- 119.4/119.4 kB 634.8 kB/s eta 0:00:00
# Installing collected packages: dill
# Successfully installed dill-0.3.9
#
# requirements: AutoUpdate success ✅ 9.5s, installed 1 package: ['dill']
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
# C:\Users\Ghost\AppData\Roaming\Python\Python38\site-packages\ultralytics\nn\tasks.py:583: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   return torch.load(file, map_location='cpu'), file  # load

# %% [markdown]
# # Read Model

# %%
img = cv2.imread('test/1.jpg')

# %% [markdown]
# # Inference

# %%
# Run batched inference on a list of images
results = model(img)  # return a list of Results objects
# Out:
# 0: 640x640 1 billboard, 247.0ms
# Speed: 11.0ms preprocess, 247.0ms inference, 15.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
def plot_img(img):
    plt.axis('off')
    plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))
    plt.show()

# %%
res_plot = results[0].plot()
boxes = results[0].boxes.data

# %%
plot_img(res_plot)

# %%
plot_img(res_plot)

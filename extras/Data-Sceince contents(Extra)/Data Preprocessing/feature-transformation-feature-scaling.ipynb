# %% [markdown]
# **Importing libraries**

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv('data/Titanic_ML.csv',usecols=['Age','Fare','Survived'])
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
data.isna().sum()
# Out:
# Survived      0
# Age         177
# Fare          0
# dtype: int64

# %%
data['Age'].fillna(data['Age'].median(),inplace=True)

# %% [markdown]
# **let's see the distribution of Age using normal distribution plot & QQ plot**

# %%
plt.figure(figsize=(10,7))
sns.distplot(data['Age'])
plt.show()

# %% [markdown]
# Here the age is approximate normally distributed on the line

# %% [markdown]
# ### 1) Logarithmic Transformation

# %%
data['Age_log'] = np.log(data['Age'])
plt.figure(figsize=(10,7))
sns.distplot(data['Age_log'])
plt.show()

# %%
data['fare_log'] = np.log(data['Fare'])
plt.figure(figsize=(10,7))
sns.distplot(data['fare_log'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[18], line 3
#       1 data['Age_log'] = np.log(data['Age'])
#       2 plt.figure(figsize=(10,7))
# ----> 3 sns.distplot(data['fare_log'])
#       4 plt.show()
#
# File d:\Anaconda\envs\Prime\Lib\site-packages\seaborn\distributions.py:2481, in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2479 if hist:
#    2480     if bins is None:
# -> 2481         bins = min(_freedman_diaconis_bins(a), 50)
#    2482     hist_kws.setdefault("alpha", 0.4)
#    2483     hist_kws.setdefault("density", norm_hist)
#
# File d:\Anaconda\envs\Prime\Lib\site-packages\seaborn\distributions.py:2387, in _freedman_diaconis_bins(a)
#    2385     return int(np.sqrt(a.size))
#    2386 else:
# -> 2387     return int(np.ceil((a.max() - a.min()) / h))
#
# ...

# %% [markdown]
# ### Exponential Transformation or Power Transformation

# %%
data['Age_Sq'] = data['Age'] ** data['Age']
plot_data(data,'Age_sq')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 data['Age_Sq'] = data['Age'] ** data['Age']
# ----> 2 plot_data(data,'Age_sq')
#
# NameError: name 'plot_data' is not defined

# %% [markdown]
# ### Box-Cox Transformation

# %%
data['Age_boxcox'],parameters = stat.boxcox(data['Age'])

# %%
print(parameters)
# Out:
# 0.7964531473656952

# %%
plot_data(data,'Age_boxcox')

# %% [markdown]
# * we can see what an transformation it has done

# %% [markdown]
# # Feature Scaling

# %% [markdown]
# ### 1) Mean Normalization

# %%
data = pd.read_csv('Titanic_ML.csv',usecols=['Age','Fare','Survived'])
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
data['Age'].fillna(data.Age.median(),inplace=True)
# Out:
# C:\Users\AJNG\AppData\Local\Temp\ipykernel_16156\14476876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data['Age'].fillna(data.Age.median(),inplace=True)

# %%
mean_age = data.Age.mean()
max_min = data.Age.max() - data.Age.min()

# %%
data['age_scaled'] = (data['Age'] - mean_age) / max_min
data.head()
# Out:
#    Survived   Age     Fare  age_scaled
# 0         0  22.0   7.2500   -0.092505
# 1         1  38.0  71.2833    0.108550
# 2         1  26.0   7.9250   -0.042242
# 3         1  35.0  53.1000    0.070852
# 4         0  35.0   8.0500    0.070852

# %% [markdown]
# * now we can have a look how it is scaled between the -1 to 1.

# %% [markdown]
# ### 2) Standardization

# %%
data = pd.read_csv('Titanic_ML.csv',usecols=['Age','Fare','Survived'])
#data.head()

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
df_scaled = scaler.fit_transform(data)
ss = pd.DataFrame(df_scaled,columns=['Survived','Age','Fare'])
ss.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df_scaled = scaler.fit_transform(data)
#       2 ss = pd.DataFrame(df_scaled,columns=['Survived','Age','Fare'])
#       3 ss.head()
#
# NameError: name 'scaler' is not defined

# %% [markdown]
# ### 3) Min-Max Scaler

# %%
data = pd.read_csv('Titanic_ML.csv',usecols=['Age','Fare','Survived'])
#data.head()

# %%
from sklearn.preprocessing import MinMaxScaler
min_max = MinMaxScaler()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#       2 min_max = MinMaxScaler()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
minmax_scaled = min_max.fit_transform(data)
minmax = pd.DataFrame(minmax_scaled)
minmax.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 minmax_scaled = min_max.fit_transform(data)
#       2 minmax = pd.DataFrame(minmax_scaled)
#       3 minmax.head()
#
# NameError: name 'min_max' is not defined

# %% [markdown]
# ### 4) Robust Scaling

# %%
data = pd.read_csv('Titanic_ML.csv',usecols=['Age','Fare','Survived'])
#data.head()

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from sklearn.preprocessing import RobustScaler
#       2 scaler = RobustScaler()
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
rob_scale = scaler.fit_transform(data)
rs = pd.DataFrame(rob_scale)
rs.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 rob_scale = scaler.fit_transform(data)
#       2 rs = pd.DataFrame(rob_scale)
#       3 rs.head()
#
# NameError: name 'scaler' is not defined
